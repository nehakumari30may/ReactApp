# %% [markdown]
# <a href="https://colab.research.google.com/github/nehakumari30may/ReactApp/blob/main/MotorCycle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
bike=pd.read_csv("/content/bike_dataset.csv")
bike.head(4)
# Out:
#               model_name   price  CC  mileage   type_of_bike  weight_in_kg  \
# 0  Gravton Motors Quanta   99000 NaN    320.0  Electric Bike           100
# 1      Simple Energy One  109999 NaN    236.0  Electric Bike           110
# 2          Okaya Classiq   69900 NaN    200.0  Electric Bike            95
# 3     Oben Electric Rorr  102999 NaN    200.0  Electric Bike           120
#
#                                                links  acceleration_speed  \
# 0  https://www.carandbike.com/gravton-motors-bike...                 4.2
# 1  https://www.carandbike.com/simple-energy-bikes...                 3.6
# 2     https://www.carandbike.com/okaya-bikes/classiq                 NaN
# 3  https://www.carandbike.com/oben-electric-bikes...                 3.0
#
#    top_speed
# 0       70.0
# 1      100.0
# 2       25.0
# 3      100.0

# %%
bike.drop(columns='links',inplace=True)

# %%
bike.tail(2)
# Out:
#                       model_name    price      CC  mileage type_of_bike  \
# 359       Ducati Hypermotard 950  1402278   937.0      9.0  Petrol Bike
# 360  Harley-Davidson CVO Limited  4999000  1923.0      8.0  Petrol Bike
#
#      weight_in_kg  acceleration_speed  top_speed
# 359           176                 NaN        NaN
# 360           411                 NaN        NaN

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_name          361 non-null    object
#  1   price               361 non-null    int64
#  2   CC                  304 non-null    float64
#  3   mileage             361 non-null    float64
#  4   type_of_bike        361 non-null    object
#  5   weight_in_kg        361 non-null    int64
#  6   acceleration_speed  170 non-null    float64
#  7   top_speed           200 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 22.7+ KB

# %%
bike[bike['CC'].isnull()]
# Out:
#                   model_name   price  CC  mileage   type_of_bike  \
# 0      Gravton Motors Quanta   99000 NaN    320.0  Electric Bike
# 1          Simple Energy One  109999 NaN    236.0  Electric Bike
# 2              Okaya Classiq   69900 NaN    200.0  Electric Bike
# 3         Oben Electric Rorr  102999 NaN    200.0  Electric Bike
# 4            Ola Electric S1   85099 NaN    181.0  Electric Bike
# 5        Ola Electric S1 Pro  120149 NaN    181.0  Electric Bike
# 6               Revolt RV300  114264 NaN    180.0  Electric Bike
# 7             Okinawa Praise   71990 NaN    170.0  Electric Bike
# 8       Hero Electric NYX HX   67540 NaN    165.0  Electric Bike
# 9         Crayon Motors Envy   53000 NaN    160.0  Electric Bike
# 10              22Kymco Flow   74740 NaN    160.0  Electric Bike
# 11           Okinawa Okhi 90  103866 NaN    160.0  Electric Bike
# 12              Revolt RV400  129463 NaN    150.0  Electric Bike
# ...

# %%
bike[bike['CC'].isnull()]['type_of_bike'].value_counts()
# Out:
# Electric Bike    57
# Name: type_of_bike, dtype: int64

# %%
bike.describe()
# Out:
#               price           CC     mileage  weight_in_kg  \
# count  3.610000e+02   304.000000  361.000000    361.000000
# mean   8.399079e+05   680.973684   44.681413    178.839335
# std    1.052083e+06   547.744364   39.890270     73.839516
# min    3.800000e+04    87.800000    8.000000     55.000000
# 25%    1.000000e+05   164.425000   20.000000    118.000000
# 50%    2.420000e+05   618.000000   30.000000    169.000000
# 75%    1.459000e+06  1051.500000   55.000000    216.000000
# max    7.990000e+06  2458.000000  320.000000    433.000000
#
#        acceleration_speed   top_speed
# count          170.000000  200.000000
# mean             4.193412   99.338650
# std              2.369334   39.631992
# min              1.010000   25.000000
# 25%              2.800000   79.500000
# 50%              3.215000  100.000000
# 75%              5.075000  129.115000
# max             13.800000  200.000000

# %%
bike['CC'].mode()
# Out:
# 0    249.0
# dtype: float64

# %%
bike['CC'].value_counts()
# Out:
# 249.0     11
# 998.0     10
# 1811.0     8
# 1745.0     8
# 937.0      7
#           ..
# 799.0      1
# 1084.0     1
# 300.0      1
# 649.3      1
# 1923.0     1
# Name: CC, Length: 129, dtype: int64

# %%
bike['brand']=bike['model_name'].str.split().apply(lambda x:x[0])

# %%
bike[bike['type_of_bike']=='Electric Bike'][bike[bike['type_of_bike']=='Electric Bike']['brand']=='Hero']
# Out:
#                  model_name  price  CC  mileage   type_of_bike  weight_in_kg  \
# 8      Hero Electric NYX HX  67540 NaN    165.0  Electric Bike            73
# 25  Hero Electric Photon HX  74240 NaN    108.0  Electric Bike            87
# 37   Hero Electric Flash LX  59640 NaN     85.0  Electric Bike            69
# 38   Hero Electric Atria LX  66640 NaN     85.0  Electric Bike            69
# 43  Hero Electric Optima HX  55580 NaN     82.0  Electric Bike            73
#
#     acceleration_speed  top_speed brand
# 8                 3.30       42.0  Hero
# 25                9.58       45.0  Hero
# 37               10.00       42.0  Hero
# 38                 NaN       25.0  Hero
# 43                8.00       42.0  Hero

# %%
bike['brand'].value_counts()
# Out:
# Kawasaki           31
# BMW                26
# Ducati             24
# Honda              23
# Hero               23
# Bajaj              20
# TVS                19
# Triumph            17
# Yamaha             16
# Harley-Davidson    16
# Indian             15
# Suzuki             11
# Aprilia            10
# KTM                10
# Royal               8
# Benelli             8
# MV                  7
# Okinawa             7
# Ampere              7
# Moto                6
# CFMoto              4
# JAWA                4
# BGauss              3
# Odysse              3
# Yezdi               3
# Evolet              3
# Ola                 2
# Piaggio             2
# Avantura            2
# Husqvarna           2
# Revolt              2
# Polarity            2
# Cleveland           2
# Kabira              2
# Nexzu               2
# Mahindra            1
# FB                  1
# Gravton             1
# Lohia               1
# Simple              1
# Bounce              1
# ...
